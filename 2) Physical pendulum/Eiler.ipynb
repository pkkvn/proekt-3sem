# %%
import matplotlib.pyplot as plt;
import numpy as np;

time, phi, ksi, enrgy, delta = np.loadtxt('data_2.txt', unpack=True)

fig, (g1, g2) = plt.subplots(1, 2)

             
g1.scatter(phi, ksi, 1)
g2.scatter(time, delta, 1)
#g3.scatter(time, ksi, 1)
             
#plt.xlabel('$\phi$')
#plt.ylabel('$\ksi$') 
plt.show()

# %%
import matplotlib.pyplot as plt;
import numpy as np;

time, phi, ksi, enrgy, delta = np.loadtxt('data_eiler11.txt', unpack=True)

time1, phi1, ksi1, enrgy1, delta1 = np.loadtxt('data_eiler20.txt', unpack=True)

fig, (g1, g2) = plt.subplots(1, 2)

             
g1.scatter(phi, ksi, 1)
g2.scatter(time, delta, 1)
#g3.scatter(time, ksi, 1)

fig, (g3, g4) = plt.subplots(1, 2)

g3.scatter(phi1, ksi1, 1)
g4.scatter(time1, delta1, 1)


#plt.xlabel('$\phi$')
#plt.ylabel('$\ksi$') 
plt.show()
